# %%
import pandas as pd
import model
import importlib
import model

importlib.reload(model)
# Out:
# <module 'model' from 'c:\\Users\\mocch\\OneDrive\\デスクトップ\\vsc_file\\data_final\\predict\\model.py'>

# %%
baseline_train = pd.read_csv('../data/baseline/train.csv')
baseline_test = pd.read_csv('../data/baseline/test.csv')

model.baseline_rf(baseline_train, baseline_test).to_csv('../result/baseline/rf-result.csv', index=False)
model.baseline_gbm(baseline_train, baseline_test).to_csv('../result/baseline/gbm-result.csv', index=False)
model.ensemble_vote(baseline_train, baseline_test).to_csv('../result/baseline/vote-result.csv', index=False)
model.ensemble_stakking(baseline_train, baseline_test).to_csv('../result/baseline/stakking-result.csv', index=False)
model.ensemble_proba_stakking(baseline_train, baseline_test).to_csv('../result/baseline/proba-stakking-result.csv', index=False)
model.ensemble_stakking_withtrain(baseline_train, baseline_test).to_csv('../result/baseline/withtrain-stakking-result.csv', index=False)
model.stakking_proba_withtrain(baseline_train, baseline_test).to_csv('../result/baseline/proba-withtrain-result.csv', index=False)

# %%
miss_train = pd.read_csv('../data/miss_column/train.csv')
miss_test = pd.read_csv('../data/miss_column/test.csv')

model.baseline_rf(miss_train, miss_test).to_csv('../result/miss_column/miss-rf-result.csv', index=False)
model.baseline_gbm(miss_train, miss_test).to_csv('../result/miss_column/miss-gbm-result.csv', index=False)
model.ensemble_vote(miss_train, miss_test).to_csv('../result/miss_column/miss-vote-result.csv', index=False)
model.ensemble_stakking(miss_train, miss_test).to_csv('../result/miss_column/miss-stakking-result.csv', index=False)

# %%
miss_age_train = pd.read_csv('../data/age_miss/train.csv')
miss_age_test = pd.read_csv('../data/age_miss/test.csv')

model.baseline_rf(miss_age_train, miss_age_test).to_csv('../result/age_miss/age-miss-rf-result.csv', index=False)
model.baseline_gbm(miss_age_train, miss_age_test).to_csv('../result/age_miss/age-miss-gbm-result.csv', index=False)
model.ensemble_vote(miss_age_train, miss_age_test).to_csv('../result/age_miss/age-miss-vote-result.csv', index=False)
model.ensemble_stakking(miss_age_train, miss_age_test).to_csv('../result/age_miss/age-miss-stakking-result.csv', index=False)

# %%
one_hot_train = pd.read_csv('../data/one_hot/train.csv')
one_hot_test = pd.read_csv('../data/one_hot/test.csv')

model.baseline_rf(one_hot_train, one_hot_test).to_csv('../result/one_hot/one-hot-rf-result.csv', index=False)
model.baseline_gbm(one_hot_train, one_hot_test).to_csv('../result/one_hot/one-hot-gbm-result.csv', index=False)
model.ensemble_vote(one_hot_train, one_hot_test).to_csv('../result/one_hot/one-hot-vote-result.csv', index=False)
model.ensemble_stakking(one_hot_train, one_hot_test).to_csv('../result/one_hot/one-hot-stakking-result.csv', index=False)

# %%
# kfoldにしたモデル

baseline_train = pd.read_csv('../data/baseline/train.csv')
baseline_test = pd.read_csv('../data/baseline/test.csv')

params = {
        'objective': 'binary',
        'metric': 'binary_error',
        'boosting_type': 'gbdt',
        'num_leaves': 32,
        'learning_rate': 0.05,
        'feature_fraction': 0.9,
        'random_state': 42
    }


model.k_gbm(baseline_train, baseline_test, lgbm_params=params).to_csv('../result/baseline/k-gbm-result.csv', index=False)
# Out:
# Fold 1/5
# [LightGBM] [Info] Number of positive: 273, number of negative: 439
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 197
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383427 -> initscore=-0.475028
# [LightGBM] [Info] Start training from score -0.475028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
model.k_vote(baseline_train, baseline_test, lgbm_params=params).to_csv('../result/baseline/k-vote-result.csv', index=False)
# Out:
# Fold 1/5
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Number of positive: 273, number of negative: 439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 197
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383427 -> initscore=-0.475028
# [LightGBM] [Info] Start training from score -0.475028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
